# %%
import cv2
import re
import json
import numpy as np
import sys

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
#img = cv2.imread('sad.jpg')
import PIL.Image as Image

x = input('Please Enter Image Name: ')

print('Opening', x , 'Image....')

img = cv2.imread("Images/" + x +".jpg")
plt.imshow(img)
# Out:
# Please Enter Image Name:  Pic1
# Opening Pic1 Image....

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  6.53it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 8.227255676729328e-06,
#    'disgust': 1.1360831386753034e-06,
#    'fear': 0.0003398627313799807,
#    'happy': 6.589827294956052e-09,
#    'sad': 5.013178240587113e-10,
#    'surprise': 99.9996542930603,
#    'neutral': 1.2546355776266735e-13},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 124, 'y': 33, 'w': 64, 'h': 64},
#   'age': 30,
#   'gender': {'Woman': 0.0021660329366568476, 'Man': 99.99783039093018},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.36491127531446665,
#    'indian': 1.5500869594566202,
#    'black': 0.09123669549743506,
#    'white': 60.96046930315907,
#    'middle eastern': 20.559426877464468,
#    'latino hispanic': 16.473873941533203},
#   'dominant_race': 'white'}]

# %%
d1={}
for i in predictions:
    d1.update(i)

# %%
d1
# Out:
# {'emotion': {'angry': 8.227255676729328e-06,
#   'disgust': 1.1360831386753034e-06,
#   'fear': 0.0003398627313799807,
#   'happy': 6.589827294956052e-09,
#   'sad': 5.013178240587113e-10,
#   'surprise': 99.9996542930603,
#   'neutral': 1.2546355776266735e-13},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 124, 'y': 33, 'w': 64, 'h': 64},
#  'age': 30,
#  'gender': {'Woman': 0.0021660329366568476, 'Man': 99.99783039093018},
#  'dominant_gender': 'Man',
#  'race': {'asian': 0.36491127531446665,
#   'indian': 1.5500869594566202,
#   'black': 0.09123669549743506,
#   'white': 60.96046930315907,
#   'middle eastern': 20.559426877464468,
#   'latino hispanic': 16.473873941533203},
#  'dominant_race': 'white'}

# %%
 faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  ##Print(facecascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)
  # draw a rectangle around face
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y),(x+w, y+h), (0, 255, 0), 2)

# %%
 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

  ## USE PUTTEXT() METHOD FOR
  ## INSERTING TEXT ON VIDEO
cv2.putText(img,
                d1['dominant_emotion'],
                (0,100),
                font, 1,
                (0, 0, 255),
                2,
                cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
